# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
import pandas as pd
from pyspark.sql.functions import col, to_date, rank, lag, lead
from pyspark.sql.window import Window

# %%
spark = (SparkSession
    .builder
    .appName("Drug Data Analysis")
    .master("local[*]")
    .getOrCreate()
)
sc = spark.sparkContext

# %%
filename = "drug-enforcement.json"

# %%
# !head -n 1000 drug-enforcement.json
# Out:
# [
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121025",
#       "report_date": "20121031",
#       "postal_code": "08816-2108",
#       "termination_date": "20141007",
#       "recall_initiation_date": "20120904",
#       "recall_number": "D-026-2013",
#       "city": "East Brunswick",
#       "event_id": "63384",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Raritan Pharmaceuticals, Inc.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Microbial Contamination of Non-Sterile Products: Product is being recalled due to possible microbial contamination by C. difficile discovered in the raw material.",
#       "initial_firm_notification": "E-Mail",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Wal-Mucil 100% Natural Fiber, 100% Natural Psyllium Seed Husk, Fiber Laxative/Supplement, a)160 capsules per bottle (item #503663), and b) 320 capsules per bottle (Item #586143), Distributed by: Walgreen Co., 200 Wilmot Road, Deerfield, IL 60015-4616, www.walgreens.com, a) UPC 3-11917-08151-9, b) UPC 3-11917-07658-4",
#       "code_info": "Lots a) 15952, 16270,16425, Exp 06/15; b)16459, 16466, 16467, Exp 07/15",
#       "address_1": "8 Joanna Ct",
#       "address_2": "",
#       "product_quantity": "56,808 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121025",
#       "report_date": "20121031",
#       "postal_code": "08816-2108",
#       "termination_date": "20141007",
#       "recall_initiation_date": "20120904",
#       "recall_number": "D-031-2013",
#       "city": "East Brunswick",
#       "event_id": "63384",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Raritan Pharmaceuticals, Inc.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Microbial Contamination of Non-Sterile Products: Product is being recalled due to possible microbial contamination by C. difficile discovered in the raw material.",
#       "initial_firm_notification": "E-Mail",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Premier Value Fiber Plus Calcium Supplement Capsules, 120 capsules per bottle, Distributed by: Chain Drug Consortium, LLC, Boca Raton, FL, UPC 8-40986-01987-6",
#       "code_info": "Lot 15087, Exp 08/15",
#       "address_1": "8 Joanna Ct",
#       "address_2": "",
#       "product_quantity": "96 bottles"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20121106",
#       "report_date": "20121114",
#       "postal_code": "08807",
#       "termination_date": "20130325",
#       "recall_initiation_date": "20121015",
#       "recall_number": "D-047-2013",
#       "city": "Bridgewater",
#       "event_id": "63488",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Valeant Pharmaceuticals",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Subpotent (Single Ingredient) Drug: This product was found to be subpotent for the salicylic acid ingredient.  Additionally, this product is mislabeled because the label either omits or erroneously added inactive ingredients to the label.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "AcneFree 3-in-1 Acne Night Repair Foam (retinol + salicylic acid 1.5% w/v), 3 oz (85 g) canister, Dist. by: University Medical Pharmaceuticals Corp., Irvine, CA  92618, UPC 7 88521 13548 6.",
#       "code_info": "All lots with expiration dates between 10/10/12 through 10/10/14 of UPC 7 88521 13548 6",
#       "address_1": "700 Rte 206 North",
#       "address_2": "",
#       "product_quantity": "81,319 canisters"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20121220",
#       "report_date": "20121226",
#       "postal_code": "08558-1311",
#       "termination_date": "20140429",
#       "recall_initiation_date": "20121204",
#       "recall_number": "D-098-2013",
#       "city": "Skillman",
#       "more_code_info": null,
#       "event_id": "63787",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Johnson & Johnson",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Superpotent (Single Ingredient Drug): salicylic acid",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Clean & Clear advantage, 3-in-1 foaming wash  8 FL. OZ. (240 mL) bottle, OTC, Distributed in the US by: Johnson & Johnson Consumer Products Company Division of Johnson & Johnson Consumer Companies Inc. Skillman, NJ 08558-9418 NDC 58232-0326-8",
#       "code_info": "0142VA, 0132VB, 0112VC, 0122VB, 0102VA, 0102VB, 0112VB  0122VA, 0092VB, 0112VA, 0092VA, 0082VA, 0072VA, 0062VA  0062VB, 0052VA, 0052VB, 0042VA, 0032VA, 0022VA, 0012VA,  0171VA, 0171VB, 0161VB, 0151VA, 0161VA, 0141VA, 0131VA  0131VB, 0121VA, 0111VA, 0101VA, 0091VA, 0081VB, 0081VA  0071VA, 0061VA, 0051VB, 0051VA, 0041VA, 0031VA, 0021VB  0011VC, 0011VB, 0190VA, 0011VA, 0180VB, 0170VB, 0180VA  0722RT, 0732RT, 0742RT, 0752RT, 1722RD, 1732RD, 1772RD  1782RD, 1792RD, 1802RD, 1802RDA, 1812RD, 1822RD, 0092RD, 0102RD, 0112RD, 0122RD, 0132RD, 0142RD, 0162RD  0172RD, 0182RD, 0192RD, 0212RD, 0202RD, 0062RD, 1451RD  1461RD, 1461RDA, 1511RD, 1521RD, 1531RD, 1661RD, 1481RD, 1571RD, 1581RD, 1591RD, 1601RD, 1611RD, 1621RD  1681RD, 1532RD, 1522RD, 1842RD, 1512RD, 1522RD, 1562RD  1582RD, 1572RD, 1722RD, 1732RD, 1742RD, 1772RD, 1782RD  1792RD, 1802RD, 1812RD, 1812RDA, 1822RD, 1842RD, 1852RD, 1872RD",
#       "address_1": "199 Grandview Rd",
#       "address_2": "",
#       "product_quantity": "1,474,462 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121231",
#       "report_date": "20130109",
#       "postal_code": "01702-8589",
#       "termination_date": "20161007",
#       "recall_initiation_date": "20120926",
#       "recall_number": "D-118-2013",
#       "city": "Framingham",
#       "event_id": "63305",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "New England Compounding Center",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "MA",
#       "reason_for_recall": "Lack of Assurance of Sterility",
#       "initial_firm_notification": "Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Hyaluronidase 150 u/ml PF, 1 mL, 5 mL, and 10 mL vials, manufactured by New England Compounding Center, Framingham, MA",
#       "code_info": "All lot codes",
#       "address_1": "697 Waverly St",
#       "address_2": "",
#       "product_quantity": "10,865 vials"
#     },
#     {
#       "classification": "Class I",
#       "center_classification_date": "20130122",
#       "report_date": "20130130",
#       "postal_code": "94080-4990",
#       "termination_date": "20130325",
#       "recall_initiation_date": "20120730",
#       "recall_number": "D-135-2013",
#       "city": "South San Francisco",
#       "event_id": "63258",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Genentech Inc",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "CA",
#       "reason_for_recall": "Presence of Particulate Matter: One lot of Bacteriostatic Water for Injection, USP diluent vials that were packed with Trastuzumab Kits for investigational use has the potential to contain glass particulates.",
#       "initial_firm_notification": "E-Mail",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Trastuzumab Kit containing 1 vial Trastuzumab (nominal content: 440 mg); 1 20 mL multiple dose vial Bacteriostatic Water for Injection, USP (1.1% benzyl alcohol), Manufactured by Hospira, Inc., for Genentech, Inc., South San Francisco, CA  94080-4990, NDC 50242-903-69; and 1 Reconstitution Instructions per kit; Investigation Use only, Genentech, Inc., 1 DNA Way, South San Francisco, CA  94080-4990.",
#       "code_info": "Lot #: 454138, Exp 07/14 (containing Trastuzumab Lot #: 886618, Exp 12/14; and Bacteriostatic Water for Injection, USP Lot #: 08-368-DK-01, Exp 07/14)",
#       "address_1": "1 DNA Way",
#       "address_2": "",
#       "product_quantity": "2,140 kits"
#     },
#     {
#       "classification": "Class I",
#       "center_classification_date": "20130130",
#       "report_date": "20130206",
#       "postal_code": "35811-8216",
#       "recall_initiation_date": "20121206",
#       "recall_number": "D-138-2013",
#       "city": "Huntsville",
#       "more_code_info": null,
#       "event_id": "63818",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Vintage Pharmaceuticals LLC DBA Qualitest Pharmaceuticals",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "AL",
#       "reason_for_recall": "Superpotent (Multiple Ingredient) Drug: Complaint received of oversized tablets.",
#       "initial_firm_notification": "Press Release",
#       "status": "Ongoing",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Hydrocodone bitartrate and acetaminophen Tablets, USP, 10 mg/500 mg, packaged in a) 30-count bottles, NDC 0603-3888-16; b) 60-count bottles, NDC 0603-3888-20; c) 90-count bottles, NDC 0603-3888-02; d) 100-count bottles, NDC 0603-3888-21; e) 120-count bottles, NDC 0603-3888-22; f) 150-count bottles, NDC 0603-3888-26; g) 180-count bottles, NDC 0603-3888-04; h) 500-count bottles, NDC 0603-3888-28; and i) 1000-count bottles, NDC 0603-3888-32, Rx only, Mfg. for: Qualitest Pharmaceuticals, Huntsville, AL 35811.",
#       "code_info": "Lot #: All that begin with the letter \"C\" a) C1160712C, Exp 12/13; b) C0930812A, C1110412A, C1141012B, C1160712A, Exp 12/13; c) C0950812B, C1110412B, C1151012B, C1160712B, C1530512A, Exp 12/13; d)  C0540212A, C0550212A, C0560212A, C0710312A, C0720312A, C0730112B, C0730312A, C0740112B, C0740312A, C0750112A, C0760112A, C0770112C, C0780112C, C0790112C, C0860812A, C0870812A, C0880812A, C0890812A, C0900812A, C0910812A, C0920812A, C0950412A, C0950812D, C0960412A, C0970412A, C0980412A, C1030412A, C1040412A, C1050412A, C1060412A, C1061012A, C1070412A, C1071012A, C1081012A, C1101012A, C1111012A, C1120412A, C1121012A, C1130412A, C1131012A, C1140412A, C1141012A, C1160712D, C1440512A, C1450512A, C1460512A, C1470512A, C1510512A, C1520512A, C1530512B, C1540512A, C1550512A, C1560512A, C1570512A, Exp 12/13; e) C0670312A, C0680312A, C0930812B, C0950812C, Exp 12/13; f) C1160712E, Exp 12/13; g) C0950812A, C1110412C, Exp 12/13; h) C0630212B, C0640212B, C0690312A, C0700312A, C0720112B,C0940812A, C0941112A, C0960812A, C1010412B, C1020412B, C1080412A, C1090412A, C1100412A, C1170712A, C1180712A, C1480512A, C1490512A, C1500512A, Exp 12/13; i) C0570212B, C0580212B, C0590212B, C0600212A, C0610212A, C0620212A, C0750312A, C0760312A, C0930812C, C0970812A, C0990412A, C1000412A, Exp 12/13",
#       "address_1": "120 Vintage Dr NE",
#       "address_2": "",
#       "product_quantity": "897,379 bottles"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20130307",
#       "report_date": "20130313",
#       "postal_code": "90262-4022",
#       "termination_date": "20131101",
#       "recall_initiation_date": "20130118",
#       "recall_number": "D-187-2013",
#       "city": "Lynwood",
#       "event_id": "64298",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Aaron Industries Inc",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "CA",
#       "reason_for_recall": "Presence of Precipitate; white substance confirmed as Guaifenesin, an active ingredient was observed in some bottles.  If the product is shaken or warmed the white particles goes into the solution.",
#       "initial_firm_notification": "Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Select Brand Cough Control CF Max, Maximum Strength for MUCUS RELIEF, (dextromethorphan HBr 10 mg, guaifenesin 200 mg, phenylephrine HCI 5 mg), 4 fl.oz 12pk (NDC 15127-025-04; UPC Code: 0-15127-02535-5), Distributed by: Select Brand Distributors, Pine Bluff, AR 71603 USA.",
#       "code_info": "Lot# 71648, 68088;  FP-47-041-02535",
#       "address_1": "11865 Alameda St",
#       "address_2": "11840 S Alameda ST",
#       "product_quantity": "5,676 bottles (473 cases)"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20130401",
#       "report_date": "20130410",
#       "postal_code": "83669-5223",
#       "termination_date": "20130807",
#       "recall_initiation_date": "20130311",
#       "recall_number": "D-233-2013",
#       "city": "Star",
#       "event_id": "64619",
#       "distribution_pattern": "Florida, Idaho, California and Hong Kong.  This product can be ordered on line.",
#       "openfda": {},
#       "recalling_firm": "Palmer Natural Products",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "ID",
#       "reason_for_recall": "Marketed Without an Approved NDA/ANDA: The products are unapproved drugs",
#       "initial_firm_notification": "Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Piracetam & Choline, 390mg Piracetam 104mg Choline Capsules, a) 30 count bottle, b) 100 count bottle, OTC, BoostYourGrade, LLC, Orlando, FL. 32826    ,",
#       "code_info": "All lot codes.",
#       "address_1": "11665 W State St",
#       "address_2": "",
#       "product_quantity": "511 30 count bottles, 4103 100 count bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20130401",
#       "report_date": "20130410",
#       "postal_code": "83669-5223",
#       "termination_date": "20130807",
#       "recall_initiation_date": "20130311",
#       "recall_number": "D-230-2013",
#       "city": "Star",
#       "event_id": "64619",
#       "distribution_pattern": "Florida, Idaho, California and Hong Kong.  This product can be ordered on line.",
#       "openfda": {},
#       "recalling_firm": "Palmer Natural Products",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "ID",
#       "reason_for_recall": "Marketed Without an Approved NDA/ANDA: The products are unapproved drugs",
#       "initial_firm_notification": "Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Aniracetam & Choline capsules, 430mg Aniracetam 88mg Choline, a) 30 count bottle b) 60 count bottle, c) 90 count, d) 180 count , OTC, BoostYourGrade, LLC  Orlando, FL 32826",
#       "code_info": "All lot codes.",
#       "address_1": "11665 W State St",
#       "address_2": "",
#       "product_quantity": "557 30 count botles, 672 60 count bottles, 1,102 90 count bottles, 250 180 count bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20120925",
#       "report_date": "20121003",
#       "postal_code": "60073-9799",
#       "termination_date": "20150504",
#       "recall_initiation_date": "20120921",
#       "recall_number": "D-1688-2012",
#       "city": "Round Lake",
#       "more_code_info": null,
#       "event_id": "63189",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Baxter Healthcare Corp.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "IL",
#       "reason_for_recall": "Chemical Contamination: The IV solutions were packaged in AVIVA containers which may contain trace levels of cumene hydroperoxide (CHP).",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "5% Dextrose and 0.45% Sodium Chloride Injection USP, packaged in a 500 mL AVIVA Container, Rx only, Baxter Healthcare Corporation, Deerfield, IL 60015 USA; product code 6E0173, NDC 0338-6308-03",
#       "code_info": "Lot #: C828814, Exp 12/12; C841551, Exp 04/13",
#       "address_1": "Route 120 And Wilson Rd",
#       "address_2": "",
#       "product_quantity": "5,064 containers"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121022",
#       "report_date": "20121031",
#       "postal_code": "35811-8216",
#       "termination_date": "20131209",
#       "recall_initiation_date": "20121011",
#       "recall_number": "D-010-2013",
#       "city": "Huntsville",
#       "event_id": "63502",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Vintage Pharmaceuticals LLC DBA Qualitest Pharmaceuticals",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "AL",
#       "reason_for_recall": "Tablet Separation: Possibility of cracked or split coating on the tablets.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Perphenazine Tablets, USP, 8 mg, 100-count tablets per bottle, Manufactured for: Qualitest Pharmaceuticals, Huntsville, AL  35811,  NDC 0603-5092-21.",
#       "code_info": "Lot C1130511A, Exp 5/13",
#       "address_1": "120 Vintage Dr NE",
#       "address_2": "",
#       "product_quantity": "2,755 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121024",
#       "report_date": "20121031",
#       "postal_code": "08901",
#       "termination_date": "20130710",
#       "recall_initiation_date": "20120605",
#       "recall_number": "D-019-2013",
#       "city": "New Brunswick",
#       "event_id": "62898",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Bristol-myers Squibb Company",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Labeling; Correct labeled product miscart/mispack: Some Physician sample cartons were incorrectly labeled as Kombiglyze XR 2.5mg/1000mg on the external package carton, whereas the contents were Kombiglyze XR 5 mg/500 mg blister packaged tablets.  The individual blister units are labeled correctly.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Kombiglyze XR (saxagliptin and metformin HCl extended-release) tablets, Physician Sample-Not For Sale, 7 Tablets per Carton, 5 mg/500 mg, Rx only, Manufactured By: Bristol-Myers Squibb Company, Princeton NJ 08543, USA, Marketed By: Bristol-Myers Squibb Company, Princeton NJ 08543, USA and AstraZeneca Pharmaceuticals LP, Wilmington DE 19850.",
#       "code_info": "Lot # 1J6024PA, 1J6025PA Exp. 09/13; 1K6049PA Exp. 10/13; 1L9015WA Exp. 11/13",
#       "address_1": "1 Squibb Dr",
#       "address_2": "",
#       "product_quantity": ""
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20121106",
#       "report_date": "20121114",
#       "postal_code": "08807",
#       "termination_date": "20130325",
#       "recall_initiation_date": "20121015",
#       "recall_number": "D-048-2013",
#       "city": "Bridgewater",
#       "event_id": "63488",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Valeant Pharmaceuticals",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Subpotent (Single Ingredient) Drug: This product was found to be subpotent for the benzoyl peroxide active ingredient.  Additionally, this product is mislabeled because the label either omits or erroneously added inactive ingredients to the label.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "AcneFree Severe Maximum Strength Acne Pore Cleanser (benzoyl peroxide 5% w/v), 3 oz (85 g) canister, Dist. by: University Medical Pharmaceuticals Corp., Irvine, CA  92618, UPC 7 88521 13350 9.",
#       "code_info": "All lots with expiration dates between 10/10/12 through 10/10/14 of UPC 7 88521 13550 9",
#       "address_1": "700 Rte 206 North",
#       "address_2": "",
#       "product_quantity": "10,434 canisters"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121203",
#       "report_date": "20121212",
#       "postal_code": "51601-1744",
#       "termination_date": "20131114",
#       "recall_initiation_date": "20120709",
#       "recall_number": "D-083-2013",
#       "city": "Shenandoah",
#       "event_id": "62511",
#       "distribution_pattern": "Distribution was nationwide, including Puerto Rico.  There was no foreign, military, or government distribution.",
#       "openfda": {},
#       "recalling_firm": "Lloyd Inc. of Iowa",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "IA",
#       "reason_for_recall": "cGMP Deviations; does not meet in process specification requirements",
#       "initial_firm_notification": "Telephone",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Levothroid (levothyroxine sodium tablets, USP), 137 mcg., 100-count bottles, Rx only, NDC 0456-1331-01,   Manufactured for Forest Pharmaceuticals, Inc., Subsidiary of Forest Laboratories, Inc., St. Louis, MO, by Lloyd Pharmaceutical, Shenandoah, IA.",
#       "code_info": "Lot #1095212 exp. 4/30/2013; and #1088877, exp. 11/30/2012",
#       "address_1": "604 W Thomas Ave",
#       "address_2": "",
#       "product_quantity": "36,978/100-tablet bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20121231",
#       "report_date": "20130109",
#       "postal_code": "01702-8589",
#       "termination_date": "20161007",
#       "recall_initiation_date": "20120926",
#       "recall_number": "D-124-2013",
#       "city": "Framingham",
#       "event_id": "63305",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "New England Compounding Center",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "MA",
#       "reason_for_recall": "Lack of Assurance of Sterility",
#       "initial_firm_notification": "Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Triamcinolone 10 mg/mL P,  40mg/mL P, 40mg/mL PF and 80 mg/mL PF in 1 mL, 2 mL, 5 mL, and 10 mL vials, manufactured by New England Compounding Center, Framingham, MA",
#       "code_info": "All lot codes",
#       "address_1": "697 Waverly St",
#       "address_2": "",
#       "product_quantity": "56,655 vials"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20130131",
#       "report_date": "20130206",
#       "postal_code": "00738",
#       "termination_date": "20150616",
#       "recall_initiation_date": "20121221",
#       "recall_number": "D-142-2013",
#       "city": "Fajardo",
#       "more_code_info": null,
#       "event_id": "64014",
#       "distribution_pattern": "US Nationwide",
#       "openfda": {},
#       "recalling_firm": "Warner Chilcott Company LLC",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "PR",
#       "reason_for_recall": "Failed Impurity/Degradation Specifications due to moisture ingress in individual bottles",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Femtrace 0.45 mg (Estradiol Acetate) Tablets, Rx Only, 100 tablets, Manufactured by Pharmaceutics International Inc, Hunt Valley, MD 21031 for Warner Chilcott Company LLC, Fajardo, PR 00738",
#       "code_info": "0.45 mg: 505969A",
#       "address_1": "Road 195, Km 1.1",
#       "address_2": "Union Street",
#       "product_quantity": "3155 bottles"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20130227",
#       "report_date": "20130306",
#       "postal_code": "07960-4535",
#       "termination_date": "20140113",
#       "recall_initiation_date": "20130104",
#       "recall_number": "D-175-2013",
#       "city": "Morristown",
#       "event_id": "64317",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Actavis Pharmaceuticals",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Failed Dissolution Specifications; 8-hours for the 18-month stability testing point.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "buPROPion Hydrochloride Extended - Release Tablets (XL) 300 mg, 30 tablet bottles, Rx Only, NDC 67767-142-30 Actavis Distributed by: Actavis South Atlantic LLC Sunrise, FL 33325 Packaged by by: America Health Packaging Columbus, OH 43217",
#       "code_info": "Lot CB1D05A,",
#       "address_1": "60 Columbia Rd Bldg B",
#       "address_2": "",
#       "product_quantity": "14,856 bottles"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20130307",
#       "report_date": "20130313",
#       "postal_code": "90262-4022",
#       "termination_date": "20131101",
#       "recall_initiation_date": "20130118",
#       "recall_number": "D-188-2013",
#       "city": "Lynwood",
#       "event_id": "64298",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Aaron Industries Inc",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "CA",
#       "reason_for_recall": "Presence of Precipitate; white substance confirmed as Guaifenesin, an active ingredient was observed in some bottles.  If the product is shaken or warmed the white particles goes into the solution.",
#       "initial_firm_notification": "Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Wal-Mart Equate Tussin CF Adult Maximum Strength, Multi-Symptom Cold, (dextromethorphan HBr 10 mg, guaifenesin 200 mg, phenylephrine HCI 5 mg), 8 FL OZ (235 mL) (NDC 49035-229-08; UPC Code: 6-81131-03884-30), Distributed by: Wal-Mart Stores, Inc., Bentonville, AR 72712.",
#       "code_info": "Lot# 81198, 82183, 80797;  FP-44-081-03884,",
#       "address_1": "11865 Alameda St",
#       "address_2": "11840 S Alameda ST",
#       "product_quantity": "43,464 bottles (3,622 cases)"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20130308",
#       "report_date": "20130320",
#       "postal_code": "23831-1534",
#       "termination_date": "20130325",
#       "recall_initiation_date": "20130122",
#       "recall_number": "D-191-2013",
#       "city": "Chester",
#       "more_code_info": null,
#       "event_id": "64541",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "RX South LLC DBA RX3 Pharmacy",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "VA",
#       "reason_for_recall": "CGMP Deviations: Pharmaceutical for injection was not manufactured according to Good Manufacturing Procedures.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Medi-bolic Booster Injectable (methionine 8.3 mg/mL, choline chloride 16.6 mg/mL, inositol 16.6 mg/mL, cyanocobalamin USP [Vit B12] 0.33 mg/mL, chromium chloride 2.6 mg/mL), 30 mL multi-dose vials, Rx3 Compounding Pharmacy, 12230 Ironbridge Rd., Suite C, Chester, VA  23831.",
#       "code_info": "Lot #: 10292012:56, Exp 01/27/13 and 10302012:77, Exp 01/28/13",
#       "address_1": "12230 Iron Bridge Rd",
#       "address_2": "Ste. C",
#       "product_quantity": "126 vials"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20131206",
#       "report_date": "20131218",
#       "postal_code": "10901-4106",
#       "termination_date": "20151221",
#       "recall_initiation_date": "20130808",
#       "recall_number": "D-338-2014",
#       "city": "Suffern",
#       "more_code_info": null,
#       "event_id": "66015",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Novartis Pharmaceuticals Corp.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NY",
#       "reason_for_recall": "Chemical Contamination: Novartis Pharmaceuticals Corporation has recalled physician sample bottles of Diovan, Exforge, Exforge HCT,Lescol XL, Stalevo, Tekturna and Tekturna HCT Tablets due to contamination with Darocur 1173 a photocuring agent used in inks on shrink-wrap sleeves.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Tekturna (aliskiren) Tablets 300 mg, 7 tablets per bottle, Physician Sample-Not For Sale, Rx only.  Manufactured by: Novartis Pharma Produktions GmbH Wehr, Germany.  Distributed by: Novartis Pharmaceuticals Corp. East Hanover, New Jersey 07936, NDC # 0078-9486-07",
#       "code_info": "Product code: 708239; Lot Number: F0140, F0140W1, Exp 09/30/2013; F0142, Exp 07/31/2014; F0143, Exp 08/31/2014; F0144, Exp 10/31/2014; F0145; Exp 01/31/2015.",
#       "address_1": "25 Old Mill Rd",
#       "address_2": "",
#       "product_quantity": "128964 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20131206",
#       "report_date": "20131218",
#       "postal_code": "10901-4106",
#       "termination_date": "20151221",
#       "recall_initiation_date": "20130808",
#       "recall_number": "D-332-2014",
#       "city": "Suffern",
#       "more_code_info": null,
#       "event_id": "66015",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Novartis Pharmaceuticals Corp.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NY",
#       "reason_for_recall": "Chemical Contamination: Novartis Pharmaceuticals Corporation has recalled physician sample bottles of Diovan, Exforge, Exforge HCT,Lescol XL, Stalevo, Tekturna and Tekturna HCT Tablets due to contamination with Darocur 1173 a photocuring agent used in inks on shrink-wrap sleeves.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Exforge HCT (amlodipine, valsartan, hydrochlorothiazide) 5/160/25 mg, Rx only, 7 tablets per bottle, Physician Sample - Not For Sale. Manufactured by: Novartis Pharma Stein AG Stein, Switzerland.  Distributed by: Novartis Pharmaceuticals Corp. East Hanover, New Jersey 07936, NDC # 0078-9560-89",
#       "code_info": "Product code: 715515; Lot Number: F0012, Exp 10/31/2013; F0013, Exp 02/28/2014; F0014, Exp 03/31/2014",
#       "address_1": "25 Old Mill Rd",
#       "address_2": "",
#       "product_quantity": "174,848 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20131226",
#       "report_date": "20140101",
#       "postal_code": "74146-6234",
#       "termination_date": "20160302",
#       "recall_initiation_date": "20131122",
#       "recall_number": "D-390-2014",
#       "city": "Tulsa",
#       "more_code_info": null,
#       "event_id": "67118",
#       "distribution_pattern": "CA, GA, NC, and MO",
#       "openfda": {},
#       "recalling_firm": "Physicians Total Care, Inc.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "OK",
#       "reason_for_recall": "Presence of Foreign Substance; heavy metals (chromium, titanium etc) and inactive components of the product were visually observed during routine stability testing.",
#       "initial_firm_notification": "FAX",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Carisoprodol IV ( Carisoprodol Tablets USP) 350mg, RX only.  Mfd by: Shasun Chemicals Drugs LTD, Pondicherry, INDIA. Repacked and Distributed by: Physicians Total Care, Inc., Tulsa, OK  74146.  90 count bottle: NDC: 54868-0816-8, 60 count bottle: NDC: 54868-0816-4, 30 count bottle: NDC: 54686-0816-3.",
#       "code_info": "NDC 54868-0816-8, LOT: 6REE,  EXP. 8/14;   NDC 54868-0816-4, LOT: 6RED,  EXP. 8/14;   NDC 54868-0816-3, LOT: 6REB,  EXP. 8/14;",
#       "address_1": "12515 E 55th St Ste 100",
#       "address_2": "",
#       "product_quantity": "3,000 tablets"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20140204",
#       "report_date": "20140212",
#       "postal_code": "60089-1944",
#       "termination_date": "20140411",
#       "recall_initiation_date": "20130909",
#       "recall_number": "D-1072-2014",
#       "city": "Buffalo Grove",
#       "more_code_info": null,
#       "event_id": "66595",
#       "distribution_pattern": "Nationwide and Puerto Rico.",
#       "openfda": {},
#       "recalling_firm": "PACK Pharmaceuticals, LLC",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "IL",
#       "reason_for_recall": "Defective Container: Stability samples of both products were noted to have some white solid product residue, identified as dried active ingredients along with the preservative, on the exterior of the bottles.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Timolol Maleate Sterile Ophthalmic Solution, USP 0.5%, 5mL, (NDC 16571-141-50).     The products are packaged in Low Density Polyethylene (LDPE) Blow Fill Seal containers equipped with a dropper tip.  The filled bottles are individually packaged into fiberboard cartons.",
#       "code_info": "Lot #:NDW3065,NDW3066,NDW3067,NDW3068,NDW3069.  Exp.05/15.",
#       "address_1": "1110 W Lake Cook Rd",
#       "address_2": "Ste 301",
#       "product_quantity": "122,551 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140204",
#       "report_date": "20140212",
#       "postal_code": "19044-1220",
#       "termination_date": "20141022",
#       "recall_initiation_date": "20131218",
#       "recall_number": "D-1075-2014",
#       "city": "Horsham",
#       "more_code_info": null,
#       "event_id": "67141",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Teva Pharmaceuticals USA",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "PA",
#       "reason_for_recall": "Failed Impurities/Degradation Specifications:There is a potential for the tablets to be out of specification for impurities throughout shelf life.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Hydralazine HCL Tablets, USP, 50 mg in a single blister package, Rx only, Manufactured in Czech Republic by: Teva Czech Industries s.r.o. Opava-Komarov, Czech Republic,  Distributed by Goldline Laboratories, Sellersville, PA, NDC 00182-0555-89  (carton) and 00182-0555-00 (single blister).",
#       "code_info": "Lot # 6A201018VA; Exp. 01/14.",
#       "address_1": "425 Privet Rd",
#       "address_2": "",
#       "product_quantity": "112,800 tablets"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140305",
#       "report_date": "20140312",
#       "postal_code": "08540-6623",
#       "termination_date": "20151120",
#       "recall_initiation_date": "20140103",
#       "recall_number": "D-1146-2014",
#       "city": "Princeton",
#       "more_code_info": null,
#       "event_id": "67303",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Dr. Reddy's Laboratories, Inc.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NJ",
#       "reason_for_recall": "Microbial Contamination of Non-Sterile Products: Out-of-specification results for microbial count were observed at the initial stability interval for Lansoprazole Delayed Release Capsules.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "a) Walgreens Lansoprazole Delayed Release Capsules, USP 15 mg/Acid Reducer, 14 capsules per Bottle, Dist by Walgreen Company, 200 Wilmot RD Deerfield IL 60015  b) Family Wellness Lansoprazole Delayed Release Capsules, USP 15 mg/Acid Reducer, 14 capsules per Bottle, Distributed by Family Services Inc .10401 Monroe Road, Matthews, NC 28105 USA  c) CVS Pharmacy Lansoprazole Delayed Release Capsules, 15 mg, Acid Reducer, 14 safety sealed capsules per Bottle, Distributed by CVS/pharmacy Inc, One CVS Drive, Woonsocket, 02895  d) CVS Pharmacy Lansoprazole Delayed Release Capsules, 15 mg, Acid Reducer, 28 safety sealed capsules per Bottle, Distributed by CVS/pharmacy Inc, One CVS Drive, Woonsocket, 02895  e) Equate Lansoprazole Delayed-Release Capsules USP, 15 mg Acid Reducer, 14 capsules per Bottle, and 28 capsules per bottle (Twin Pack)Distributed by Wal-mart Stores Inc. Bentonville, AR 72716  f) CVS Pharmacy Lansoprazole Delayed Release Capsules, 15 mg, Acid Reducer, 42 safety sealed capsules per Bottle, Distributed by CVS/pharmacy Inc, One CVS Drive, Woonsocket, 02895",
#       "code_info": "Lot #: a) 79305114A, b) 79305114B, c) 79305114C, d) 79305114D, e) 79305114E, f) 79305114F, Exp 05/2015",
#       "address_1": "107 College Rd E",
#       "address_2": "",
#       "product_quantity": "58,656 Bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140304",
#       "report_date": "20140312",
#       "postal_code": "28803-2558",
#       "termination_date": "20140424",
#       "recall_initiation_date": "20131101",
#       "recall_number": "D-1125-2014",
#       "city": "Asheville",
#       "more_code_info": null,
#       "event_id": "66856",
#       "distribution_pattern": "NC",
#       "openfda": {},
#       "recalling_firm": "Natures Pharmacy & Compounding Center",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NC",
#       "reason_for_recall": "Lack of Sterility Assurance: All lots of sterile products compounded by the pharmacy that are not expired due to concerns associated with quality control procedures that present a potential risk to sterility assurance that were observed during a recent FDA inspection.",
#       "initial_firm_notification": "Telephone",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Novarel (IM)",
#       "code_info": "All lot numbers within expiry.",
#       "address_1": "752 Biltmore Ave",
#       "address_2": "",
#       "product_quantity": ""
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140304",
#       "report_date": "20140312",
#       "postal_code": "28803-2558",
#       "termination_date": "20140424",
#       "recall_initiation_date": "20131101",
#       "recall_number": "D-1129-2014",
#       "city": "Asheville",
#       "more_code_info": null,
#       "event_id": "66856",
#       "distribution_pattern": "NC",
#       "openfda": {},
#       "recalling_firm": "Natures Pharmacy & Compounding Center",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NC",
#       "reason_for_recall": "Lack of Sterility Assurance: All lots of sterile products compounded by the pharmacy that are not expired due to concerns associated with quality control procedures that present a potential risk to sterility assurance that were observed during a recent FDA inspection.",
#       "initial_firm_notification": "Telephone",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Pyridoxine (p-f) 100mg/ml",
#       "code_info": "All lot numbers within expiry.",
#       "address_1": "752 Biltmore Ave",
#       "address_2": "",
#       "product_quantity": ""
#     },
#     {
#       "classification": "Class I",
#       "center_classification_date": "20140312",
#       "report_date": "20140319",
#       "postal_code": "30096",
#       "termination_date": "20150129",
#       "recall_initiation_date": "20130801",
#       "recall_number": "D-1154-2014",
#       "city": "Duluth",
#       "event_id": "65900",
#       "distribution_pattern": "Nationwide and  Australia, Canada.",
#       "openfda": {},
#       "recalling_firm": "CTV Best Group",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "GA",
#       "reason_for_recall": "Marketed without an Approved NDA/ANDA: Product contains an undeclared drug, sibutramine, making it an unapproved new drug.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "BEST Slim, Dietary Supplement, 100% Natural Weight Loss Pill, 40 Pills per bottle, Distributed by CTV Best Group Inc., P.O. Box 956452, Duluth, GA 30095.",
#       "code_info": "All lots (lot 109400, Exp 12/31/2016)",
#       "address_1": "3802 Satellite Blvd",
#       "address_2": "Suite 101",
#       "product_quantity": "593 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140407",
#       "report_date": "20140416",
#       "postal_code": "98248-8919",
#       "termination_date": "20140730",
#       "recall_initiation_date": "20140303",
#       "recall_number": "D-1200-2014",
#       "city": "Ferndale",
#       "event_id": "67723",
#       "distribution_pattern": "Products were distributed US Nationwide, to Canada, to Philippines, and through internet sales.",
#       "openfda": {},
#       "recalling_firm": "Terra-Medica Inc.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "WA",
#       "reason_for_recall": "Penicillin Cross Contamination",
#       "initial_firm_notification": "E-Mail",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Pleo Quent SUPPOSITORIES 3X, 10 Suppository Cartons, Oral Homeopathic Medicine, OTC Only.  Made in Germany for: SANUM USA Copr, 1456 Slater Road, Ferndale, WA 98248 by Sanum-Kehlbeck GmbH & Co. KG. NDC: 49807-2904-1.",
#       "code_info": "Batch # 2089; EXP: June 2014; Batch #3031 , EXP: June 2016.",
#       "address_1": "1465 Slater Rd",
#       "address_2": "",
#       "product_quantity": "3725 cartons"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20131206",
#       "report_date": "20131218",
#       "postal_code": "10901-4106",
#       "termination_date": "20151221",
#       "recall_initiation_date": "20130808",
#       "recall_number": "D-331-2014",
#       "city": "Suffern",
#       "more_code_info": null,
#       "event_id": "66015",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Novartis Pharmaceuticals Corp.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NY",
#       "reason_for_recall": "Chemical Contamination: Novartis Pharmaceuticals Corporation has recalled physician sample bottles of Diovan, Exforge, Exforge HCT,Lescol XL, Stalevo, Tekturna and Tekturna HCT Tablets due to contamination with Darocur 1173 a photocuring agent used in inks on shrink-wrap sleeves.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Exforge HCT (amlodipine, valsartan, hydrochlorothiazide) 5/160/12.5 mg, Rx only, 7 tablets per bottle, Physician Sample - Not For Sale. Manufactured by: Novartis Pharma Stein AG Stein, Switzerland.  Distributed by: Novartis Pharmaceuticals Corp. East Hanover, New Jersey 07936, NDC # 0078-9559-89",
#       "code_info": "Product code: 715523 & 725278; Lot Number: F0019, F0019A, Exp 08/31/2013; F0020, Exp 09/30/2013; F0021, F0021A, Exp 10/31/2013; F0022, F0025, Exp 11/30/2013; F0024, F0026, Exp 12/31/2013; F0027, Exp 09/30/2014",
#       "address_1": "25 Old Mill Rd",
#       "address_2": "",
#       "product_quantity": "328,543 bottles"
#     },
#     {
#       "classification": "Class I",
#       "center_classification_date": "20131212",
#       "report_date": "20131218",
#       "postal_code": "90813",
#       "termination_date": "20150123",
#       "recall_initiation_date": "20130719",
#       "recall_number": "D-344-2014",
#       "city": "Long Beach",
#       "more_code_info": null,
#       "event_id": "65762",
#       "distribution_pattern": "Nationwide",
#       "openfda": {},
#       "recalling_firm": "Myson Corporation, Inc.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "CA",
#       "reason_for_recall": "Marketed Without An Approved NDA/ANDA: All lots of Volcano Liquid and Volcano Capsules, marketed as dietary supplements, are being recalled because they were found to contain undeclared active pharmaceutical ingredients, making them unapproved new drugs.",
#       "initial_firm_notification": "Press Release",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Volcano Male Enhancement Liquid, 2 FL OZ (60 ml) bottle, www.volcanoenhancement.com, DISTRIBUTED BY VOLCANO Long Beach, CA 90813, UPC 6 09613 85996 0.",
#       "code_info": "All lots including 0312-K2, Exp 11/14",
#       "address_1": "1329 Oregon Ave",
#       "address_2": "",
#       "product_quantity": "70 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20131206",
#       "report_date": "20131218",
#       "postal_code": "10901-4106",
#       "termination_date": "20151221",
#       "recall_initiation_date": "20130808",
#       "recall_number": "D-333-2014",
#       "city": "Suffern",
#       "more_code_info": null,
#       "event_id": "66015",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Novartis Pharmaceuticals Corp.",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NY",
#       "reason_for_recall": "Chemical Contamination: Novartis Pharmaceuticals Corporation has recalled physician sample bottles of Diovan, Exforge, Exforge HCT,Lescol XL, Stalevo, Tekturna and Tekturna HCT Tablets due to contamination with Darocur 1173 a photocuring agent used in inks on shrink-wrap sleeves.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Exforge (amlodipine and valsartan Tablets) 10/160 mg, Rx only, 7 tablets per bottle, Physician Sample - Not For Sale. Manufactured by: Novartis Pharma Stein AG Stein, Switzerland.  Distributed by: Novartis Pharmaceuticals Corp. East Hanover, New Jersey 07936, NDC # 0078-9489-07",
#       "code_info": "Product code: 710011; Lot Number: F0060, Exp 01/31/2014; F0028A, Exp 02/28/2014; F0061, Exp 03/31/2014; F0062, Exp 05/31/2014; F0033A, Exp 10/31/2014; F0037A, Exp 01/31/2015",
#       "address_1": "25 Old Mill Rd",
#       "address_2": "",
#       "product_quantity": "61,1240 bottles"
#     },
#     {
#       "classification": "Class III",
#       "center_classification_date": "20131231",
#       "report_date": "20140108",
#       "postal_code": "35811-8216",
#       "termination_date": "20141007",
#       "recall_initiation_date": "20131216",
#       "recall_number": "D-394-2014",
#       "city": "Huntsville",
#       "more_code_info": null,
#       "event_id": "67102",
#       "distribution_pattern": "Nationwide and Puerto Rico",
#       "openfda": {},
#       "recalling_firm": "Qualitest Pharmaceuticals",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "AL",
#       "reason_for_recall": "Failed impurities/degradation specifications; out of specification for the known impurity 4-chlorobenzophenone.",
#       "initial_firm_notification": "Letter",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Cetirizine Hydrochloride Syrup (Cetirizine Hydrochloride Oral Solution, USP) 1 mg/mL, 120 mL and 480 mL bottles, Rx only. Mfg. for: Qualitest Pharmaceuticals, Huntsville, AL 35811. NDC 0603-9063-54 (120 mL), NDC 0603-9063-58 (480 mL).",
#       "code_info": "Lot Numbers:    NDC 0603-9063-54 (120 mL):  L081K12A, exp. 4/14; L082K12A, exp. 4/14; L062M12A, exp. 6/14; L063M12A, exp. 6/14; L064M12A, exp. 6/14; L054A13A, exp. 7/14; L055A13A, exp. 7/14; L057A13A, exp. 7/14; L058A13A, exp. 7/14; L075B13A, exp. 8/14; L076B13A, exp 8/14; L003C13A, exp. 8/14; L004C13A, exp. 8/14; and L005C13A, exp. 8/14    NDC 0603-9063-58 (480 mL):  L081K12B, exp. 4/14; L082K12B, exp. 4/14; L059A13A, exp. 7/14; L114E13A, exp. 10/14; L026G13A, exp. 12/14; and L081J13A, exp. 3/15.",
#       "address_1": "120 Vintage Dr NE",
#       "address_2": "",
#       "product_quantity": "438,055 bottles"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140109",
#       "report_date": "20140115",
#       "postal_code": "27607-6481",
#       "termination_date": "20170419",
#       "recall_initiation_date": "20131018",
#       "recall_number": "D-401-2014",
#       "city": "Raleigh",
#       "more_code_info": null,
#       "event_id": "66568",
#       "distribution_pattern": "NC",
#       "openfda": {},
#       "recalling_firm": "Compounding Centre At Blue Ridge",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NC",
#       "reason_for_recall": "Lack of Assurance of Sterility; All lots of sterile products compounded by the pharmacy within expiry are subject to this recall. This recall is initiated due to concerns associated with quality control procedures observed during a recent FDA inspection.",
#       "initial_firm_notification": "Telephone",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Triple Mix Injectable (aka Dr Ungers Triple Rx;  Dr Tortora's Triple Rx; Dr Bennett's Triple Rx; Dr Neighbors Triple Rx Injectable; Dr Leatherman's Triple Rx Injectable; Dr Kane's Triple Rx Injectable; Dr Khoudary's Triple Rx Injectable) Rx Only, The Compounding Center at Blue Ridge, 2601 Blue Ridge Rd, Raleigh, NC 27607.",
#       "code_info": "All Lots",
#       "address_1": "2601 Blue Ridge Rd",
#       "address_2": "",
#       "product_quantity": "92 units"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140109",
#       "report_date": "20140115",
#       "postal_code": "27607-6481",
#       "termination_date": "20170419",
#       "recall_initiation_date": "20131018",
#       "recall_number": "D-404-2014",
#       "city": "Raleigh",
#       "more_code_info": null,
#       "event_id": "66568",
#       "distribution_pattern": "NC",
#       "openfda": {},
#       "recalling_firm": "Compounding Centre At Blue Ridge",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NC",
#       "reason_for_recall": "Lack of Assurance of Sterility; All lots of sterile products compounded by the pharmacy within expiry are subject to this recall. This recall is initiated due to concerns associated with quality control procedures observed during a recent FDA inspection.",
#       "initial_firm_notification": "Telephone",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Quad Mix Injectable, 5 mL, Rx Only, The Compounding Center at Blue Ridge, 2601 Blue Ridge Rd, Raleigh, NC 27607.",
#       "code_info": "All Lots",
#       "address_1": "2601 Blue Ridge Rd",
#       "address_2": "",
#       "product_quantity": "1 unit"
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140304",
#       "report_date": "20140312",
#       "postal_code": "28803-2558",
#       "termination_date": "20140424",
#       "recall_initiation_date": "20131101",
#       "recall_number": "D-1131-2014",
#       "city": "Asheville",
#       "more_code_info": null,
#       "event_id": "66856",
#       "distribution_pattern": "NC",
#       "openfda": {},
#       "recalling_firm": "Natures Pharmacy & Compounding Center",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NC",
#       "reason_for_recall": "Lack of Sterility Assurance: All lots of sterile products compounded by the pharmacy that are not expired due to concerns associated with quality control procedures that present a potential risk to sterility assurance that were observed during a recent FDA inspection.",
#       "initial_firm_notification": "Telephone",
#       "status": "Terminated",
#       "product_type": "Drugs",
#       "country": "United States",
#       "product_description": "Sodium Bicarbonate 8.4% inj.",
#       "code_info": "All lot numbers within expiry.",
#       "address_1": "752 Biltmore Ave",
#       "address_2": "",
#       "product_quantity": ""
#     },
#     {
#       "classification": "Class II",
#       "center_classification_date": "20140304",
#       "report_date": "20140312",
#       "postal_code": "28803-2558",
#       "termination_date": "20140424",
#       "recall_initiation_date": "20131101",
#       "recall_number": "D-1139-2014",
#       "city": "Asheville",
#       "more_code_info": null,
#       "event_id": "66856",
#       "distribution_pattern": "NC",
#       "openfda": {},
#       "recalling_firm": "Natures Pharmacy & Compounding Center",
#       "voluntary_mandated": "Voluntary: Firm Initiated",
#       "state": "NC",
#       "reason_for_recall": "Lack of Sterility Assurance: All lots of sterile products compounded by the pharmacy that are not expired due to concerns associated with quality control procedures that present a potential risk to sterility assurance that were observed during a recent FDA inspection.",
#       "initial_firm_notification": "Telephone",

# %%
drug_data = spark.read.json(filename,multiLine = True)

# %%
drug_data.printSchema()
# Out:
# root
#  |-- address_1: string (nullable = true)
#  |-- address_2: string (nullable = true)
#  |-- center_classification_date: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- classification: string (nullable = true)
#  |-- code_info: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- distribution_pattern: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- initial_firm_notification: string (nullable = true)
#  |-- more_code_info: string (nullable = true)
#  |-- openfda: struct (nullable = true)
#  |    |-- application_number: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- brand_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- generic_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- is_original_packager: array (nullable = true)
#  |    |    |-- element: boolean (containsNull = true)
#  |    |-- manufacturer_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- nui: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- original_packager_product_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- package_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_cs: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_epc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_moa: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_pe: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- product_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- product_type: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- route: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- rxcui: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- spl_id: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- spl_set_id: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- substance_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- unii: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- upc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- postal_code: string (nullable = true)
#  |-- product_description: string (nullable = true)
#  |-- product_quantity: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- reason_for_recall: string (nullable = true)
#  |-- recall_initiation_date: string (nullable = true)
#  |-- recall_number: string (nullable = true)
#  |-- recalling_firm: string (nullable = true)
#  |-- report_date: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- termination_date: string (nullable = true)
#  |-- voluntary_mandated: string (nullable = true)

# %%
drug_data = drug_data.withColumn('report_date', to_date(col('report_date'), 'yyyy-MM-dd'))

# %%
drug_data.printSchema() ## it can be infered that the report date column type has changed from type string into date
# Out:
# root
#  |-- address_1: string (nullable = true)
#  |-- address_2: string (nullable = true)
#  |-- center_classification_date: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- classification: string (nullable = true)
#  |-- code_info: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- distribution_pattern: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- initial_firm_notification: string (nullable = true)
#  |-- more_code_info: string (nullable = true)
#  |-- openfda: struct (nullable = true)
#  |    |-- application_number: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- brand_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- generic_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- is_original_packager: array (nullable = true)
#  |    |    |-- element: boolean (containsNull = true)
#  |    |-- manufacturer_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- nui: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- original_packager_product_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- package_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_cs: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_epc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_moa: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_pe: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- product_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- product_type: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- route: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- rxcui: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- spl_id: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- spl_set_id: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- substance_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- unii: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- upc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- postal_code: string (nullable = true)
#  |-- product_description: string (nullable = true)
#  |-- product_quantity: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- reason_for_recall: string (nullable = true)
#  |-- recall_initiation_date: string (nullable = true)
#  |-- recall_number: string (nullable = true)
#  |-- recalling_firm: string (nullable = true)
#  |-- report_date: date (nullable = true)
#  |-- state: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- termination_date: string (nullable = true)
#  |-- voluntary_mandated: string (nullable = true)

# %%
city_report_counts = drug_data.groupBy('city').count()

# %%
windowSpec = Window.orderBy(col('count').desc())
ranked_city_reports = city_report_counts.withColumn('city_rank', rank().over(windowSpec))

# %%
ranked_city_reports.show() ## showing the rank per city based on each report count
# Out:
# +-----------+-----+---------+
# |       city|count|city_rank|
# +-----------+-----+---------+
# |  Vancouver|  539|        1|
# |  Asheville|  507|        2|
# |    Toronto|  499|        3|
# |Lake Forest|  458|        4|
# |  Knoxville|  383|        5|
# |      Ocala|  325|        6|
# |    Newbern|  299|        7|
# |    Houston|  241|        8|
# |Little Rock|  217|        9|
# |  Princeton|  150|       10|
# |  Aquebogue|  140|       11|
# | Boca Raton|  132|       12|
# | Naperville|  118|       13|
# |Noblesville|  117|       14|
# |  Las Vegas|  115|       15|
# |    Orlando|  115|       15|
# |       Mesa|  107|       17|
# | Birmingham|  105|       18|
# |  Henderson|  105|       18|
# | Moses Lake|  101|       20|
# +-----------+-----+---------+
# only showing top 20 rows

# %%
unique_values = drug_data.select('classification').distinct().collect()

# %%
unique_values ## here one need to see the unique values of the classification model, so one can filter over the Class III
# Out:
# [Row(classification='Class II'),
#  Row(classification='Class I'),
#  Row(classification='Not Yet Classified'),
#  Row(classification='Class III')]

# %%
class_iii_counts = drug_data.filter(col('classification') == 'Class III') \
    .groupBy('city').count()

# %%
class_iii_counts.show()
# Out:
# +------------------+-----+
# |              city|count|
# +------------------+-----+
# |            Corona|   17|
# |        Charleston|    1|
# |     Center Valley|    1|
# |            Wilson|    1|
# |       Cherry Hill|    1|
# |         Levittown|    1|
# |        Brookhaven|    5|
# |      Chesterbrook|    1|
# |      Cedar Knolls|    2|
# |     North Chicago|    5|
# |Whitehouse Station|    4|
# |      Fort Collins|    1|
# |     Central Islip|    3|
# |              Kadi|    1|
# |             Davie|    3|
# |        Morgantown|   17|
# |      Olive Branch|    2|
# |            Dallas|    1|
# |      Chesterfield|    1|
# |           Peapack|    6|
# +------------------+-----+
# only showing top 20 rows

# %%
city_report_Date_Window = Window.partitionBy('city').orderBy('report_date')

drug_data_new = drug_data.withColumn('prev_report_date', lag('report_date').over(city_report_Date_Window)) \
    .withColumn('next_report_date', lead('report_date').over(city_report_Date_Window))

# %%
drug_data_new.show()
# Out:
# +--------------------+---------+--------------------------+---------+--------------+--------------------+-------------+--------------------+--------+-------------------------+--------------+--------------------+-----------+--------------------+----------------+------------+--------------------+----------------------+-------------+--------------------+-----------+-----+----------+----------------+--------------------+----------------+----------------+
# |           address_1|address_2|center_classification_date|     city|classification|           code_info|      country|distribution_pattern|event_id|initial_firm_notification|more_code_info|             openfda|postal_code| product_description|product_quantity|product_type|   reason_for_recall|recall_initiation_date|recall_number|      recalling_firm|report_date|state|    status|termination_date|  voluntary_mandated|prev_report_date|next_report_date|
# +--------------------+---------+--------------------------+---------+--------------+--------------------+-------------+--------------------+--------+-------------------------+--------------+--------------------+-----------+--------------------+----------------+------------+--------------------+----------------------+-------------+--------------------+-----------+-----+----------+----------------+--------------------+----------------+----------------+
# |Opp. Iim-B, Bilek...|         |                  20191010|Bangalore|      Class II|Lot: 7008334, Exp...|        India|Nationwide in the...|   83914|                   Letter|          null|[[ANDA065421], [R...|           |Rifampin for Inje...|    19,165 vials|       Drugs|Failed Impurities...|              20191007|  D-0139-2020|Mylan Laboratorie...|       null|     |   Ongoing|            null|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Tetracaine 2%/Pon...|         5 units|       Drugs|The firm received...|              20130528|   D-310-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|L-Carnitine 30ml,...|        19 units|       Drugs|The firm received...|              20130528|   D-155-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Methylprednisolon...|        91 units|       Drugs|The firm received...|              20130528|   D-222-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|B-12 (compounded)...|      2157 units|       Drugs|The firm received...|              20130528|   D-042-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Post-menopausal H...|       489 units|       Drugs|The firm received...|              20130528|   D-256-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|HCG 280 iu prefil...|      2873 units|       Drugs|The firm received...|              20130528|   D-129-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Minoxidil 10% 60m...|        11 units|       Drugs|The firm received...|              20130528|   D-243-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Mic B w/Amp Mix, ...|        36 units|       Drugs|The firm received...|              20130528|   D-231-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|TCA 30% - 0.8PH 1...|          1 unit|       Drugs|The firm received...|              20130528|   D-279-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Testosterone Pell...|        31 units|       Drugs|The firm received...|              20130528|   D-307-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Oral B-12 30ml--c...|        82 units|       Drugs|The firm received...|              20130528|   D-252-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|HCG 1500iu PFS, M...|        52 units|       Drugs|The firm received...|              20130528|   D-112-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Mitomycin/Mannito...|        26 units|       Drugs|The firm received...|              20130528|   D-251-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Methylcobalamin 1...|         4 units|       Drugs|The firm received...|              20130528|   D-206-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Mitomycin 2ml (fu...|        32 units|       Drugs|The firm received...|              20130528|   D-247-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|MALE HCG PK 2nd m...|        21 units|       Drugs|The firm received...|              20130528|   D-191-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|EDTA 150mg/ml 100...|        25 units|       Drugs|The firm received...|              20130528|   D-083-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Methylprednisolon...|        20 units|       Drugs|The firm received...|              20130528|   D-217-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# |126 East Main Street|         |                  20131203|  Newbern|      Class II|all codes distrib...|United States|nationwide, speci...|   65479|                Telephone|          null|[,,,,,,,,,,,,,,,,...|      38059|Carnitine 250mg/m...|        30 units|       Drugs|The firm received...|              20130528|   D-068-2014|Main Street Famil...|       null|   TN|Terminated|        20140422|Voluntary: Firm i...|            null|            null|
# +--------------------+---------+--------------------------+---------+--------------+--------------------+-------------+--------------------+--------+-------------------------+--------------+--------------------+-----------+--------------------+----------------+------------+--------------------+----------------------+-------------+--------------------+-----------+-----+----------+----------------+--------------------+----------------+----------------+
# only showing top 20 rows

# %%
drug_data_new.printSchema() ## it can be shown that new columns were added named as prev_report_data & next_reporrt_date
# Out:
# root
#  |-- address_1: string (nullable = true)
#  |-- address_2: string (nullable = true)
#  |-- center_classification_date: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- classification: string (nullable = true)
#  |-- code_info: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- distribution_pattern: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- initial_firm_notification: string (nullable = true)
#  |-- more_code_info: string (nullable = true)
#  |-- openfda: struct (nullable = true)
#  |    |-- application_number: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- brand_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- generic_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- is_original_packager: array (nullable = true)
#  |    |    |-- element: boolean (containsNull = true)
#  |    |-- manufacturer_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- nui: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- original_packager_product_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- package_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_cs: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_epc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_moa: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- pharm_class_pe: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- product_ndc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- product_type: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- route: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- rxcui: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- spl_id: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- spl_set_id: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- substance_name: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- unii: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- upc: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- postal_code: string (nullable = true)
#  |-- product_description: string (nullable = true)
#  |-- product_quantity: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- reason_for_recall: string (nullable = true)
#  |-- recall_initiation_date: string (nullable = true)
#  |-- recall_number: string (nullable = true)
#  |-- recalling_firm: string (nullable = true)
#  |-- report_date: date (nullable = true)
#  |-- state: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- termination_date: string (nullable = true)
#  |-- voluntary_mandated: string (nullable = true)
#  |-- prev_report_date: date (nullable = true)
#  |-- next_report_date: date (nullable = true)
